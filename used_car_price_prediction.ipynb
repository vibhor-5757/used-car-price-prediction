# %% [markdown]
# link of data used:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %% [markdown]
# # load dataset

# %%
datapath = '/content/drive/MyDrive/ml_code/regression model/train-data.csv'
datapath2 = '/content/drive/MyDrive/ml_code/regression model/test-data.csv'

df = pd.read_csv(datapath)
df_test = pd.read_csv(datapath2)

# %%
index = df["Unnamed: 0"];
df.drop(df.columns[0],axis = 1,inplace = True)
df.insert(0,"index",index)

index = df_test["Unnamed: 0"];
df_test.drop(df_test.columns[0],axis = 1,inplace = True)
df_test.insert(0,"index",index)

target_variable = df["Price"]

# %% [markdown]
# # **understanding data**

# %%
df.head(10)
# Out:
#    index                                 Name    Location  Year  \
# 0      0               Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                         Honda Jazz V     Chennai  2011
# 3      3                    Maruti Ertiga VDI     Chennai  2012
# 4      4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5      5      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6      6               Nissan Micra Diesel XV      Jaipur  2013
# 7      7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8      8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9      9       Tata Indica Vista Quadrajet LS     Chennai  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 5              75000       LPG       Manual      First  21.1 km/kg   814 CC
# 6              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
# 7              36000    Diesel    Automatic      First  11.36 kmpl  2755 CC
# 8              64430    Diesel       Manual      First  20.54 kmpl  1598 CC
# 9              65932    Diesel       Manual     Second   22.3 kmpl  1248 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74
# 5   55.2 bhp    5.0        NaN   2.35
# 6   63.1 bhp    5.0        NaN   3.50
# 7  171.5 bhp    8.0    21 Lakh  17.50
# 8  103.6 bhp    5.0        NaN   5.20
# 9     74 bhp    5.0        NaN   1.95

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB
# None

# %%
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1234 non-null   int64
#  1   Name               1234 non-null   object
#  2   Location           1234 non-null   object
#  3   Year               1234 non-null   int64
#  4   Kilometers_Driven  1234 non-null   int64
#  5   Fuel_Type          1234 non-null   object
#  6   Transmission       1234 non-null   object
#  7   Owner_Type         1234 non-null   object
#  8   Mileage            1234 non-null   object
#  9   Engine             1224 non-null   object
#  10  Power              1224 non-null   object
#  11  Seats              1223 non-null   float64
#  12  New_Price          182 non-null    object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 125.5+ KB
# None

# %% [markdown]
# # handeling missing data

# %% [markdown]
# ###finding amount of missing data in each column

# %%
max_non_null_val = df["index"].count()
print("Percentage of missing values in each column:\n")
missing_percent = []
for col in df.columns:
  missing_percent.append(df[col].isnull().sum()/max_non_null_val*100)
  print(f"{col} : {df[col].isnull().sum()/max_non_null_val*100:.2f}%")
# Out:
# Percentage of missing values in each column:
#
# index : 0.00%
# Name : 0.00%
# Location : 0.00%
# Year : 0.00%
# Kilometers_Driven : 0.00%
# Fuel_Type : 0.00%
# Transmission : 0.00%
# Owner_Type : 0.00%
# Mileage : 0.03%
# Engine : 0.60%
# Power : 0.60%
# Seats : 0.70%
# New_Price : 86.31%
# Price : 0.00%

# %% [markdown]
# ###dropping columns with more than 40% missing values

# %%
from operator import indexOf
index_list =[]
for i in missing_percent:
  if(i>40):
    index_list.append(indexOf(missing_percent,i))
df_test.drop(df.columns[index_list],axis=1,inplace=True)
df.drop(df.columns[index_list],axis=1,inplace=True)
print(df.info())
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 611.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1234 non-null   int64
#  1   Name               1234 non-null   object
#  2   Location           1234 non-null   object
#  3   Year               1234 non-null   int64
#  4   Kilometers_Driven  1234 non-null   int64
#  5   Fuel_Type          1234 non-null   object
#  6   Transmission       1234 non-null   object
#  7   Owner_Type         1234 non-null   object
#  8   Mileage            1234 non-null   object
#  9   Engine             1224 non-null   object
#  10  Power              1224 non-null   object
#  11  Seats              1223 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 115.8+ KB
# None

# %% [markdown]
# ###classifying columns based on numerical or categorical data

# %%
def classify_cols(df , cat_thresh = 15, card_thresh  = 20 ):
  cat_cols = [col for col in df.columns if df[col].dtypes == "O"]
  num_but_cat_cols = [col for col in df.columns if df[col].dtypes != "O" and df[col].nunique()<cat_thresh]
  cat_but_card_cols = [col for col in df.columns if df[col].dtypes == "O" and df[col].nunique()>card_thresh]
  # cat_cols = cat_cols + num_but_cat_cols
  cat_cols = [col for col in cat_cols if col not in cat_but_card_cols]
  num_cols = [col for col in df.columns if df[col].dtypes != "O" and col not in num_but_cat_cols]
  return cat_cols, num_cols, cat_but_card_cols,num_but_cat_cols

cat_cols, num_cols, cat_but_card_cols, num_but_cat_cols = classify_cols(df)
print(f"cat_cols: {(cat_cols)}")
print(f"num_cols: {(num_cols)}")
print(f"cat_but_car: {(cat_but_card_cols)}")
print(f"num_but_cat_cols: {(num_but_cat_cols)}")
# Out:
# cat_cols: ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type']
# num_cols: ['index', 'Year', 'Kilometers_Driven', 'Price']
# cat_but_car: ['Name', 'Mileage', 'Engine', 'Power']
# num_but_cat_cols: ['Seats']

# %% [markdown]
# # Dropping Name column

# %%
df.drop(columns = ["Name"],inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 564.4+ KB

# %%
df_test.drop(columns = ["Name"],inplace = True)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1234 non-null   int64
#  1   Location           1234 non-null   object
#  2   Year               1234 non-null   int64
#  3   Kilometers_Driven  1234 non-null   int64
#  4   Fuel_Type          1234 non-null   object
#  5   Transmission       1234 non-null   object
#  6   Owner_Type         1234 non-null   object
#  7   Mileage            1234 non-null   object
#  8   Engine             1224 non-null   object
#  9   Power              1224 non-null   object
#  10  Seats              1223 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 106.2+ KB

# %%
def get_int(str):
  l=[]
  l = str.split(" ")
  if l[0]== 'null':
        return np.nan
  return l[0]

# %%
for col in ['Mileage', 'Engine', 'Power']:
  df[col] = df[col].astype(str).apply(get_int)
  df_test[col] = df_test[col].astype(str).apply(get_int)

for col in ['Mileage', 'Engine', 'Power']:
    df[col] = df[col].astype(float)
    df_test[col] = df_test[col].astype(float)

df.head(10)
# Out:
#    index    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0      0      Mumbai  2010              72000       CNG       Manual
# 1      1        Pune  2015              41000    Diesel       Manual
# 2      2     Chennai  2011              46000    Petrol       Manual
# 3      3     Chennai  2012              87000    Diesel       Manual
# 4      4  Coimbatore  2013              40670    Diesel    Automatic
# 5      5   Hyderabad  2012              75000       LPG       Manual
# 6      6      Jaipur  2013              86999    Diesel       Manual
# 7      7      Mumbai  2016              36000    Diesel    Automatic
# 8      8        Pune  2013              64430    Diesel       Manual
# 9      9     Chennai  2012              65932    Diesel       Manual
#
#   Owner_Type  Mileage  Engine   Power  Seats  Price
# 0      First    26.60   998.0   58.16    5.0   1.75
# 1      First    19.67  1582.0  126.20    5.0  12.50
# 2      First    18.20  1199.0   88.70    5.0   4.50
# 3      First    20.77  1248.0   88.76    7.0   6.00
# 4     Second    15.20  1968.0  140.80    5.0  17.74
# 5      First    21.10   814.0   55.20    5.0   2.35
# 6      First    23.08  1461.0   63.10    5.0   3.50
# 7      First    11.36  2755.0  171.50    8.0  17.50
# 8      First    20.54  1598.0  103.60    5.0   5.20
# 9     Second    22.30  1248.0   74.00    5.0   1.95

# %%
def classify_cols(df , cat_thresh = 15, card_thresh  = 20 ):
  cat_cols = [col for col in df.columns if df[col].dtypes == "O"]
  num_but_cat_cols = [col for col in df.columns if df[col].dtypes != "O" and df[col].nunique()<cat_thresh]
  cat_but_card_cols = [col for col in df.columns if df[col].dtypes == "O" and df[col].nunique()>card_thresh]
  # cat_cols = cat_cols + num_but_cat_cols
  cat_cols = [col for col in cat_cols if col not in cat_but_card_cols]
  num_cols = [col for col in df.columns if df[col].dtypes != "O" and col not in num_but_cat_cols]
  return cat_cols, num_cols, cat_but_card_cols,num_but_cat_cols

cat_cols, num_cols, cat_but_card_cols, num_but_cat_cols = classify_cols(df)
print(f"cat_cols: {(cat_cols)}")
print(f"num_cols: {(num_cols)}")
print(f"cat_but_car: {(cat_but_card_cols)}")
print(f"num_but_cat_cols: {(num_but_cat_cols)}")
# Out:
# cat_cols: ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type']
# num_cols: ['index', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Price']
# cat_but_car: []
# num_but_cat_cols: ['Seats']

# %% [markdown]
# ###Filling missing values in numerical columns with the mean value

# %%
for col in num_cols:
  df[col] = df[col].fillna(df[col].mean())
  if(col != "Price"):
    df_test[col] = df_test[col].fillna(df[col].mean())
df.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   float64
#  9   Power              6019 non-null   float64
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 564.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1234 non-null   int64
#  1   Location           1234 non-null   object
#  2   Year               1234 non-null   int64
#  3   Kilometers_Driven  1234 non-null   int64
#  4   Fuel_Type          1234 non-null   object
#  5   Transmission       1234 non-null   object
#  6   Owner_Type         1234 non-null   object
#  7   Mileage            1234 non-null   float64
#  8   Engine             1234 non-null   float64
#  9   Power              1234 non-null   float64
#  10  Seats              1223 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 106.2+ KB

# %% [markdown]
# ###Filling missing values in categorical columns with mode value

# %%
for col in cat_cols:
  df[col] = df[col].fillna(df[col].mode()[0])
  df_test[col] = df_test[col].fillna(df[col].mode()[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   float64
#  9   Power              6019 non-null   float64
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 564.4+ KB

# %%
for col in num_but_cat_cols:
  df[col] = df[col].fillna(df[col].mode()[0])
  df_test[col] = df_test[col].fillna(df[col].mode()[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   float64
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 564.4+ KB

# %%
for col in cat_but_card_cols:
  df[col] = df[col].fillna(df[col].mode()[0])
  df_test[col] = df_test[col].fillna(df[col].mode()[0])
df.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6019 non-null   int64
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   float64
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 564.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1234 non-null   int64
#  1   Location           1234 non-null   object
#  2   Year               1234 non-null   int64
#  3   Kilometers_Driven  1234 non-null   int64
#  4   Fuel_Type          1234 non-null   object
#  5   Transmission       1234 non-null   object
#  6   Owner_Type         1234 non-null   object
#  7   Mileage            1234 non-null   float64
#  8   Engine             1234 non-null   float64
#  9   Power              1234 non-null   float64
#  10  Seats              1234 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 106.2+ KB

# %% [markdown]
# # Descriptive stats

# %%
stats = df.describe()
print(stats)
# Out:
#              index         Year  Kilometers_Driven      Mileage       Engine  \
# count  6019.000000  6019.000000       6.019000e+03  6019.000000  6019.000000
# mean   3009.000000  2013.358199       5.873838e+04    18.134961  1621.276450
# std    1737.679967     3.269742       9.126884e+04     4.581528   599.553865
# min       0.000000  1998.000000       1.710000e+02     0.000000    72.000000
# 25%    1504.500000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3009.000000  2014.000000       5.300000e+04    18.150000  1493.000000
# 75%    4513.500000  2016.000000       7.300000e+04    21.100000  1969.000000
# max    6018.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              Power        Seats        Price
# count  6019.000000  6019.000000  6019.000000
# mean    113.253050     5.276790     9.479468
# std      53.231019     0.806346    11.187917
# min      34.200000     0.000000     0.440000
# 25%      78.000000     5.000000     3.500000
# 50%      98.600000     5.000000     5.640000
# 75%     138.030000     5.000000     9.950000
# max     560.000000    10.000000   160.000000

# %% [markdown]
# #correlation matrix of numerical columns

# %% [markdown]
# ###making df with only numerical columns

# %%
num_df = df[num_cols]
num_df
# Out:
#       index  Year  Kilometers_Driven  Mileage  Engine   Power  Price
# 0         0  2010              72000    26.60   998.0   58.16   1.75
# 1         1  2015              41000    19.67  1582.0  126.20  12.50
# 2         2  2011              46000    18.20  1199.0   88.70   4.50
# 3         3  2012              87000    20.77  1248.0   88.76   6.00
# 4         4  2013              40670    15.20  1968.0  140.80  17.74
# ...     ...   ...                ...      ...     ...     ...    ...
# 6014   6014  2014              27365    28.40  1248.0   74.00   4.75
# 6015   6015  2015             100000    24.40  1120.0   71.00   4.00
# 6016   6016  2012              55000    14.00  2498.0  112.00   2.90
# 6017   6017  2013              46000    18.90   998.0   67.10   2.65
# 6018   6018  2011              47000    25.44   936.0   57.60   2.50
#
# [6019 rows x 7 columns]

# %% [markdown]
# ###making correlation matrix of numerical df

# %%
num_corr_df = num_df.corr()
num_corr_df
# Out:
#                       index      Year  Kilometers_Driven   Mileage    Engine  \
# index              1.000000  0.002354          -0.008734  0.023673 -0.004163
# Year               0.002354  1.000000          -0.173048  0.321534 -0.051712
# Kilometers_Driven -0.008734 -0.173048           1.000000 -0.065253  0.091029
# Mileage            0.023673  0.321534          -0.065253  1.000000 -0.588354
# Engine            -0.004163 -0.051712           0.091029 -0.588354  1.000000
# Power             -0.012765  0.013895           0.033419 -0.506801  0.859020
# Price             -0.020275  0.305327          -0.011493 -0.306588  0.657118
#
#                       Power     Price
# index             -0.012765 -0.020275
# Year               0.013895  0.305327
# Kilometers_Driven  0.033419 -0.011493
# Mileage           -0.506801 -0.306588
# Engine             0.859020  0.657118
# Power              1.000000  0.767331
# Price              0.767331  1.000000

# %% [markdown]
# #removing numerical columns that have less than 5% correlation with target value

# %%
corr_coef_with_target_value = num_corr_df["Price"].values
indexes_with_lessthan_5_corr = []
for i in corr_coef_with_target_value:
  if (abs(i)<0.1):
    indexes_with_lessthan_5_corr.append(indexOf(corr_coef_with_target_value,i))
num_df.columns[indexes_with_lessthan_5_corr]
df.drop(num_df.columns[indexes_with_lessthan_5_corr], axis=1,inplace=True)
df_test.drop(num_df.columns[indexes_with_lessthan_5_corr], axis=1,inplace=True)
num_df.drop(num_df.columns[indexes_with_lessthan_5_corr], axis=1,inplace=True)
df.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Location      6019 non-null   object
#  1   Year          6019 non-null   int64
#  2   Fuel_Type     6019 non-null   object
#  3   Transmission  6019 non-null   object
#  4   Owner_Type    6019 non-null   object
#  5   Mileage       6019 non-null   float64
#  6   Engine        6019 non-null   float64
#  7   Power         6019 non-null   float64
#  8   Seats         6019 non-null   float64
#  9   Price         6019 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 470.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Location      1234 non-null   object
#  1   Year          1234 non-null   int64
#  2   Fuel_Type     1234 non-null   object
#  3   Transmission  1234 non-null   object
#  4   Owner_Type    1234 non-null   object
#  5   Mileage       1234 non-null   float64
#  6   Engine        1234 non-null   float64
#  7   Power         1234 non-null   float64
#  8   Seats         1234 non-null   float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 86.9+ KB
# <ipython-input-23-9e4a634be17b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_df.drop(num_df.columns[indexes_with_lessthan_5_corr], axis=1,inplace=True)

# %% [markdown]
# # encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

columns_to_encode = cat_cols
columns_to_encode = [col for col in columns_to_encode if col not in cat_but_card_cols]

columns_to_encode

encoder = OneHotEncoder(sparse_output=False, drop="first")
encoder = encoder.fit(df[columns_to_encode])

encoded_categorical_data = encoder.transform(df[columns_to_encode])
encoded_categorical_data_test = encoder.transform(df_test[columns_to_encode])

encoded_categorical_df = pd.DataFrame(encoded_categorical_data,
                                      columns=encoder.get_feature_names_out(columns_to_encode))
encoded_categorical_df_test = pd.DataFrame(encoded_categorical_data_test,
                                      columns=encoder.get_feature_names_out(columns_to_encode))

encoded_categorical_df.index = df.index
encoded_categorical_df_test.index = df_test.index


df.drop(columns=columns_to_encode, inplace=True)
df_test.drop(columns=columns_to_encode , inplace =True)

df = pd.concat([df, encoded_categorical_df], axis=1)
df_test = pd.concat([df_test,encoded_categorical_df_test], axis = 1)

Price = df["Price"]
df.drop(columns=["Price"], inplace=True)
df = pd.concat([df, Price], axis=1)

print(df.info(10))
print(df_test.info(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       6019 non-null   int64
#  1   Mileage                    6019 non-null   float64
#  2   Engine                     6019 non-null   float64
#  3   Power                      6019 non-null   float64
#  4   Seats                      6019 non-null   float64
#  5   Location_Bangalore         6019 non-null   float64
#  6   Location_Chennai           6019 non-null   float64
#  7   Location_Coimbatore        6019 non-null   float64
#  8   Location_Delhi             6019 non-null   float64
#  9   Location_Hyderabad         6019 non-null   float64
#  10  Location_Jaipur            6019 non-null   float64
#  11  Location_Kochi             6019 non-null   float64
#  12  Location_Kolkata           6019 non-null   float64
#  13  Location_Mumbai            6019 non-null   float64
#  14  Location_Pune              6019 non-null   float64
#  15  Fuel_Type_Diesel           6019 non-null   float64
#  16  Fuel_Type_Electric         6019 non-null   float64
#  17  Fuel_Type_LPG              6019 non-null   float64
#  18  Fuel_Type_Petrol           6019 non-null   float64
#  19  Transmission_Manual        6019 non-null   float64
#  20  Owner_Type_Fourth & Above  6019 non-null   float64
#  21  Owner_Type_Second          6019 non-null   float64
#  22  Owner_Type_Third           6019 non-null   float64
#  23  Price                      6019 non-null   float64
# dtypes: float64(23), int64(1)
# memory usage: 1.1 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1234 non-null   int64
#  1   Mileage                    1234 non-null   float64
#  2   Engine                     1234 non-null   float64
#  3   Power                      1234 non-null   float64
#  4   Seats                      1234 non-null   float64
#  5   Location_Bangalore         1234 non-null   float64
#  6   Location_Chennai           1234 non-null   float64
#  7   Location_Coimbatore        1234 non-null   float64
#  8   Location_Delhi             1234 non-null   float64
#  9   Location_Hyderabad         1234 non-null   float64
#  10  Location_Jaipur            1234 non-null   float64
#  11  Location_Kochi             1234 non-null   float64
#  12  Location_Kolkata           1234 non-null   float64
#  13  Location_Mumbai            1234 non-null   float64
#  14  Location_Pune              1234 non-null   float64
#  15  Fuel_Type_Diesel           1234 non-null   float64
#  16  Fuel_Type_Electric         1234 non-null   float64
#  17  Fuel_Type_LPG              1234 non-null   float64
#  18  Fuel_Type_Petrol           1234 non-null   float64
#  19  Transmission_Manual        1234 non-null   float64
#  20  Owner_Type_Fourth & Above  1234 non-null   float64
#  21  Owner_Type_Second          1234 non-null   float64
#  22  Owner_Type_Third           1234 non-null   float64
# dtypes: float64(22), int64(1)
# memory usage: 221.9 KB
# None

# %% [markdown]
# #correlation matrix of whole dataframe after encoding

# %%
df_corr = df.corr()
df_corr
# Out:
#                                Year       Mileage    Engine     Power  \
# Year                       1.000000  3.215336e-01 -0.051712  0.013895
# Mileage                    0.321534  1.000000e+00 -0.588354 -0.506801
# Engine                    -0.051712 -5.883536e-01  1.000000  0.859020
# Power                      0.013895 -5.068014e-01  0.859020  1.000000
# Seats                      0.015204 -2.996312e-01  0.392982  0.100188
# Location_Bangalore        -0.042806 -7.741145e-02  0.080467  0.088377
# Location_Chennai          -0.131993 -7.707808e-03  0.000351 -0.027181
# Location_Coimbatore        0.214594 -2.467598e-02  0.055696  0.078231
# Location_Delhi            -0.002714 -1.603626e-02  0.046141  0.040338
# Location_Hyderabad        -0.077870  2.845426e-02  0.006981 -0.027747
# Location_Jaipur           -0.072753  5.104819e-02 -0.075578 -0.097116
# Location_Kochi             0.228541  3.850476e-02 -0.022668  0.009833
# Location_Kolkata          -0.028684  6.883785e-02 -0.074825 -0.065730
# Location_Mumbai           -0.007220 -6.603191e-02  0.030976  0.058221
# Location_Pune             -0.112649 -1.466075e-02 -0.041632 -0.056653
# Fuel_Type_Diesel           0.126185  1.131064e-01  0.426749  0.288974
# Fuel_Type_Electric         0.000791  3.032703e-17 -0.020870 -0.019268
# Fuel_Type_LPG             -0.031919  1.113136e-02 -0.040411 -0.040880
# Fuel_Type_Petrol          -0.127490 -1.439093e-01 -0.406900 -0.268738
# Transmission_Manual       -0.097059  3.330962e-01 -0.499082 -0.638835
# Owner_Type_Fourth & Above -0.077886 -4.910103e-02  0.019378 -0.004626
# Owner_Type_Second         -0.297913 -1.225220e-01  0.042432  0.030194
# Owner_Type_Third          -0.231184 -8.415812e-02  0.019114  0.003455
# Price                      0.305327 -3.065881e-01  0.657118  0.767331
#
#                               Seats  Location_Bangalore  Location_Chennai  \
# Year                       0.015204           -0.042806         -0.131993
# Mileage                   -0.299631           -0.077411         -0.007708
# Engine                     0.392982            0.080467          0.000351
# Power                      0.100188            0.088377         -0.027181
# Seats                      1.000000            0.015603          0.013713
# Location_Bangalore         0.015603            1.000000         -0.075196
# Location_Chennai           0.013713           -0.075196          1.000000
# Location_Coimbatore        0.010699           -0.086439         -0.102781
# Location_Delhi             0.036109           -0.080067         -0.095204
# Location_Hyderabad         0.017313           -0.094298         -0.112126
# Location_Jaipur           -0.011668           -0.068256         -0.081161
# Location_Kochi            -0.028655           -0.087575         -0.104131
# Location_Kolkata          -0.043505           -0.078546         -0.093395
# Location_Mumbai           -0.002846           -0.097746         -0.116226
# Location_Pune             -0.004849           -0.085372         -0.101512
# Fuel_Type_Diesel           0.308869            0.039944          0.031487
# Fuel_Type_Electric        -0.006259           -0.004585          0.027760
# Fuel_Type_LPG             -0.014004           -0.010259         -0.012198
# Fuel_Type_Petrol          -0.302446           -0.034309         -0.028405
# Transmission_Manual        0.074838           -0.064833          0.028359
# Owner_Type_Fourth & Above  0.040043            0.008448          0.019759
# Owner_Type_Second         -0.006132            0.107890          0.068465
# Owner_Type_Third           0.011725            0.027321          0.119189
# Price                      0.052811            0.086526         -0.046130
#
#                            Location_Coimbatore  Location_Delhi  \
# Year                                  0.214594       -0.002714
# Mileage                              -0.024676       -0.016036
# Engine                                0.055696        0.046141
# Power                                 0.078231        0.040338
# Seats                                 0.010699        0.036109
# Location_Bangalore                   -0.086439       -0.080067
# Location_Chennai                     -0.102781       -0.095204
# Location_Coimbatore                   1.000000       -0.109440
# Location_Delhi                       -0.109440        1.000000
# Location_Hyderabad                   -0.128892       -0.119390
# Location_Jaipur                      -0.093296       -0.086419
# Location_Kochi                       -0.119702       -0.110878
# Location_Kolkata                     -0.107361       -0.099446
# Location_Mumbai                      -0.133604       -0.123755
# Location_Pune                        -0.116690       -0.108088
# Fuel_Type_Diesel                      0.018785        0.012677
# Fuel_Type_Electric                   -0.006267       -0.005805
# Fuel_Type_LPG                        -0.014022       -0.012988
# Fuel_Type_Petrol                     -0.011021       -0.017016
# Transmission_Manual                  -0.078064       -0.016141
# Owner_Type_Fourth & Above             0.000686       -0.012321
# Owner_Type_Second                    -0.057793        0.007671
# Owner_Type_Third                     -0.043563       -0.031337
# Price                                 0.172026        0.006496
#
#                            Location_Hyderabad  ...  Location_Pune  \
# Year                                -0.077870  ...      -0.112649
# Mileage                              0.028454  ...      -0.014661
# Engine                               0.006981  ...      -0.041632
# Power                               -0.027747  ...      -0.056653
# Seats                                0.017313  ...      -0.004849
# Location_Bangalore                  -0.094298  ...      -0.085372
# Location_Chennai                    -0.112126  ...      -0.101512
# Location_Coimbatore                 -0.128892  ...      -0.116690
# Location_Delhi                      -0.119390  ...      -0.108088
# Location_Hyderabad                   1.000000  ...      -0.127300
# Location_Jaipur                     -0.101779  ...      -0.092144
# Location_Kochi                      -0.130585  ...      -0.118223
# Location_Kolkata                    -0.117121  ...      -0.106034
# Location_Mumbai                     -0.145751  ...      -0.131954
# Location_Pune                       -0.127300  ...       1.000000
# Fuel_Type_Diesel                     0.112327  ...      -0.047260
# Fuel_Type_Electric                  -0.006836  ...      -0.006189
# Fuel_Type_LPG                        0.059155  ...      -0.000448
# Fuel_Type_Petrol                    -0.113148  ...       0.039701
# Transmission_Manual                  0.017937  ...       0.040766
# Owner_Type_Fourth & Above           -0.014511  ...       0.015113
# Owner_Type_Second                   -0.048603  ...       0.103950
# Owner_Type_Third                    -0.051868  ...       0.069660
# Price                                0.009958  ...      -0.083550
#
#                            Fuel_Type_Diesel  Fuel_Type_Electric  \
# Year                               0.126185        7.907273e-04
# Mileage                            0.113106        3.032703e-17
# Engine                             0.426749       -2.087046e-02
# Power                              0.288974       -1.926825e-02
# Seats                              0.308869       -6.258788e-03
# Location_Bangalore                 0.039944       -4.584795e-03
# Location_Chennai                   0.031487        2.776002e-02
# Location_Coimbatore                0.018785       -6.266735e-03
# Location_Delhi                     0.012677       -5.804767e-03
# Location_Hyderabad                 0.112327       -6.836493e-03
# Location_Jaipur                    0.013285       -4.948499e-03
# Location_Kochi                    -0.045721       -6.349057e-03
# Location_Kolkata                  -0.033789       -5.694468e-03
# Location_Mumbai                   -0.106164        1.990936e-02
# Location_Pune                     -0.047260       -6.189335e-03
# Fuel_Type_Diesel                   1.000000       -1.945705e-02
# Fuel_Type_Electric                -0.019457        1.000000e+00
# Fuel_Type_LPG                     -0.043536       -7.437447e-04
# Fuel_Type_Petrol                  -0.977528       -1.669945e-02
# Transmission_Manual               -0.141613       -2.882335e-02
# Owner_Type_Fourth & Above          0.001790       -7.055195e-04
# Owner_Type_Second                 -0.025779       -7.981306e-03
# Owner_Type_Third                  -0.042125       -2.521840e-03
# Price                              0.320645        5.533751e-03
#
#                            Fuel_Type_LPG  Fuel_Type_Petrol  \
# Year                           -0.031919         -0.127490
# Mileage                         0.011131         -0.143909
# Engine                         -0.040411         -0.406900
# Power                          -0.040880         -0.268738
# Seats                          -0.014004         -0.302446
# Location_Bangalore             -0.010259         -0.034309
# Location_Chennai               -0.012198         -0.028405
# Location_Coimbatore            -0.014022         -0.011021
# Location_Delhi                 -0.012988         -0.017016
# Location_Hyderabad              0.059155         -0.113148
# Location_Jaipur                 0.021201         -0.009790
# Location_Kochi                 -0.014206          0.045107
# Location_Kolkata               -0.012742          0.040932
# Location_Mumbai                -0.003775          0.096396
# Location_Pune                  -0.000448          0.039701
# Fuel_Type_Diesel               -0.043536         -0.977528
# Fuel_Type_Electric             -0.000744         -0.016699
# Fuel_Type_LPG                   1.000000         -0.037366
# Fuel_Type_Petrol               -0.037366          1.000000
# Transmission_Manual             0.025804          0.128988
# Owner_Type_Fourth & Above      -0.001579         -0.000915
# Owner_Type_Second               0.004350          0.024858
# Owner_Type_Third               -0.005643          0.042878
# Price                          -0.025499         -0.309363
#
#                            Transmission_Manual  Owner_Type_Fourth & Above  \
# Year                                 -0.097059                  -0.077886
# Mileage                               0.333096                  -0.049101
# Engine                               -0.499082                   0.019378
# Power                                -0.638835                  -0.004626
# Seats                                 0.074838                   0.040043
# Location_Bangalore                   -0.064833                   0.008448
# Location_Chennai                      0.028359                   0.019759
# Location_Coimbatore                  -0.078064                   0.000686
# Location_Delhi                       -0.016141                  -0.012321
# Location_Hyderabad                    0.017937                  -0.014511
# Location_Jaipur                       0.096039                   0.006505
# Location_Kochi                       -0.022461                  -0.013476
# Location_Kolkata                      0.094183                  -0.012087
# Location_Mumbai                      -0.084128                   0.010425
# Location_Pune                         0.040766                   0.015113
# Fuel_Type_Diesel                     -0.141613                   0.001790
# Fuel_Type_Electric                   -0.028823                  -0.000706
# Fuel_Type_LPG                         0.025804                  -0.001579
# Fuel_Type_Petrol                      0.128988                  -0.000915
# Transmission_Manual                   1.000000                   0.014960
# Owner_Type_Fourth & Above             0.014960                   1.000000
# Owner_Type_Second                    -0.008391                  -0.016941
# Owner_Type_Third                      0.019755                  -0.005353
# Price                                -0.586025                  -0.021445
#
#                            Owner_Type_Second  Owner_Type_Third     Price
# Year                               -0.297913         -0.231184  0.305327
# Mileage                            -0.122522         -0.084158 -0.306588
# Engine                              0.042432          0.019114  0.657118
# Power                               0.030194          0.003455  0.767331
# Seats                              -0.006132          0.011725  0.052811
# Location_Bangalore                  0.107890          0.027321  0.086526
# Location_Chennai                    0.068465          0.119189 -0.046130
# Location_Coimbatore                -0.057793         -0.043563  0.172026
# Location_Delhi                      0.007671         -0.031337  0.006496
# Location_Hyderabad                 -0.048603         -0.051868  0.009958
# Location_Jaipur                     0.054705          0.035088 -0.089049
# Location_Kochi                     -0.102943         -0.036346  0.052911
# Location_Kolkata                   -0.085881         -0.043204 -0.106606
# Location_Mumbai                    -0.008104         -0.003014 -0.001742
# Location_Pune                       0.103950          0.069660 -0.083550
# Fuel_Type_Diesel                   -0.025779         -0.042125  0.320645
# Fuel_Type_Electric                 -0.007981         -0.002522  0.005534
# Fuel_Type_LPG                       0.004350         -0.005643 -0.025499
# Fuel_Type_Petrol                    0.024858          0.042878 -0.309363
# Transmission_Manual                -0.008391          0.019755 -0.586025
# Owner_Type_Fourth & Above          -0.016941         -0.005353 -0.021445
# Owner_Type_Second                   1.000000         -0.060554 -0.073552
# Owner_Type_Third                   -0.060554          1.000000 -0.055297
# Price                              -0.073552         -0.055297  1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# # dropping columns with less than 10% correlation

# %%
corr_coef_with_target_value = df_corr["Price"].values
indexes_with_lessthan_30_corr = []
for i in corr_coef_with_target_value:
  if (abs(i)<0.1):
    indexes_with_lessthan_30_corr.append(indexOf(corr_coef_with_target_value,i))
df.drop(df.columns[indexes_with_lessthan_30_corr], axis=1,inplace=True)
df_test.drop(df_test.columns[indexes_with_lessthan_30_corr], axis =1, inplace = True)
df.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 6019 non-null   int64
#  1   Mileage              6019 non-null   float64
#  2   Engine               6019 non-null   float64
#  3   Power                6019 non-null   float64
#  4   Location_Coimbatore  6019 non-null   float64
#  5   Location_Kolkata     6019 non-null   float64
#  6   Fuel_Type_Diesel     6019 non-null   float64
#  7   Fuel_Type_Petrol     6019 non-null   float64
#  8   Transmission_Manual  6019 non-null   float64
#  9   Price                6019 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 470.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1234 non-null   int64
#  1   Mileage              1234 non-null   float64
#  2   Engine               1234 non-null   float64
#  3   Power                1234 non-null   float64
#  4   Location_Coimbatore  1234 non-null   float64
#  5   Location_Kolkata     1234 non-null   float64
#  6   Fuel_Type_Diesel     1234 non-null   float64
#  7   Fuel_Type_Petrol     1234 non-null   float64
#  8   Transmission_Manual  1234 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 86.9 KB

# %% [markdown]
# # Splitting training data into training and testing datasets

# %%
y = df['Price']
df_X = df.drop(columns=['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# #Data scaling

# %%
scaler = StandardScaler()
scaler = scaler.fit(X_train)

scaled_array_train = scaler.transform(X_train)
scaled_array_test = scaler.transform(X_test)

X_train = pd.DataFrame(scaled_array_train, columns=X_train.columns)
X_test = pd.DataFrame(scaled_array_test, columns=X_test.columns)

scaled_array_test = scaler.transform(df_test)
df_test = pd.DataFrame(scaled_array_test, columns=df_test.columns)

# %% [markdown]
# #Trainnig multiple regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"Linear Regression - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# Linear Regression - MAE: 3.598931527008787, RMSE: 5.8505172154092255, R²: 0.7261393259747739

# %% [markdown]
# #Training a Descision Tree model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"descision tree Regression - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# descision tree Regression - MAE: 2.0560306872898235, RMSE: 5.827973498816888, R²: 0.7282457867929254

# %% [markdown]
# #Training a random forest model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(max_depth=30, max_features='sqrt', min_samples_leaf=1, min_samples_split=2, n_estimators=1000)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, max_features='sqrt', n_estimators=1000)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [500, 700, 1000],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(regressor, param_grid, cv=5,verbose = 2)
grid_search.fit(X_train, y_train)
best_regressor = grid_search.best_estimator_
best_parameters_rf = grid_search.best_params_

print("Best Parameters:", best_parameters_rf)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   9.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   4.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   5.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   7.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   7.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   3.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   3.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   3.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   4.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   3.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   3.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   3.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   4.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   7.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   6.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   3.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   4.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   4.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# ...
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.3s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   4.3s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   2.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   5.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   2.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   4.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.4s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   3.4s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   3.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.4s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   3.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        n
print(f"random forest Regression - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# random forest Regression - MAE: 0.7789303795556172, RMSE: 1.6424692989235201, R²: 0.9784482626121408

# %% [markdown]
# ###building best model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"random forest Regression - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# random forest Regression - MAE: 1.6041726242010403, RMSE: 3.9792449456011094, R²: 0.8733099533381604

# %% [markdown]
# #Training a svm model

# %%
from sklearn.svm import SVR
regressor = SVR(C=100, epsilon=1, gamma=0.01, kernel='linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=100, epsilon=1, gamma=0.01, kernel='linear')

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 2.7 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 11.7 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-3.6.1

# %%
import optuna
def svr_objective(trial):
    params = {
        'C': trial.suggest_float('C', 0.1, 100),
        'epsilon': trial.suggest_float('epsilon', 0.01, 1),
        'kernel': trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']),
        'degree': trial.suggest_int('degree', 2, 5) if trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']) == 'poly' else 3,
        'gamma': trial.suggest_categorical('gamma', ['scale', 'auto'])
    }

    svr_model = SVR(**params)
    svr_model.fit(X_train, y_train)
    y_pred = svr_model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

svr_study = optuna.create_study(direction='minimize')
svr_study.optimize(svr_objective, n_trials=50)
best_parameters_svr = svr_study.best_params
print("Best hyperparameters for SVR: ", svr_study.best_params)
# Out:
# [I 2024-07-30 11:47:38,302] A new study created in memory with name: no-name-ed447367-b1aa-497e-bfc4-0df18132080e
# [I 2024-07-30 11:48:39,492] Trial 0 finished with value: 44.18094148545178 and parameters: {'C': 99.36962336541723, 'epsilon': 0.1647724464495137, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 0 with value: 44.18094148545178.
# [I 2024-07-30 11:48:43,588] Trial 1 finished with value: 31173101.117640033 and parameters: {'C': 97.15165444572065, 'epsilon': 0.5093828744477639, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 0 with value: 44.18094148545178.
# [I 2024-07-30 11:48:45,005] Trial 2 finished with value: 20.434279674663216 and parameters: {'C': 83.04206515232055, 'epsilon': 0.7804322601172766, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:48:47,073] Trial 3 finished with value: 20643927.261338394 and parameters: {'C': 79.0481933274398, 'epsilon': 0.5963164133798825, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:48:54,791] Trial 4 finished with value: 25.939565581572193 and parameters: {'C': 31.693151651153105, 'epsilon': 0.21359099203554732, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:48:56,796] Trial 5 finished with value: 20759135.416566763 and parameters: {'C': 79.29932876705436, 'epsilon': 0.8228607736242194, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:48:57,539] Trial 6 finished with value: 24.893399352453592 and parameters: {'C': 8.524002166328243, 'epsilon': 0.9422605129662118, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:48:59,207] Trial 7 finished with value: 42.65751347287856 and parameters: {'C': 4.592255965023507, 'epsilon': 0.9128070352827147, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:49:13,294] Trial 8 finished with value: 24.54836919890555 and parameters: {'C': 74.48301663268366, 'epsilon': 0.539848799623757, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:49:31,381] Trial 9 finished with value: 44.02780998569269 and parameters: {'C': 79.73746223108877, 'epsilon': 0.18667903585419424, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 20.434279674663216.
# [I 2024-07-30 11:54:22,398] Trial 48 finished with value: 30298177.05076966 and parameters: {'C': 95.82158582708574, 'epsilon': 0.6227739011987631, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 32 with value: 20.13604997627462.
# [I 2024-07-30 11:54:24,760] Trial 49 finished with value: 20.466276327426137 and parameters: {'C': 80.48054095471412, 'epsilon': 0.8445625544843184, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 32 with value: 20.13604997627462.
# Best hyperparameters for SVR:  {'C': 99.98000958846642, 'epsilon': 0.9359223548529659, 'kernel': 'rbf', 'gamma': 'scale'}

# %%
regressor = SVR(**best_parameters_svr)
regressor.fit(X_train, y_train)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"svr Regression - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# svr Regression - MAE: 2.0026050622048275, RMSE: 4.487321024428119, R²: 0.8388926218963053

# %% [markdown]
# #Stacking models

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import Ridge

base_models = [
    ('linear', LinearRegression()),
    ('svr', SVR(**best_parameters_svr)),
    ('rf', RandomForestRegressor(**best_parameters_rf))
]

stack_model = StackingRegressor(
    estimators=base_models,
    final_estimator=Ridge()
)

stack_model.fit(X_train, y_train)

y_pred = stack_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"Stacking Regressor - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# Stacking Regressor - MAE: 1.6352664151091745, RMSE: 4.039853971930086, R²: 0.8694212570340741

# %% [markdown]
# #Training XG Boost model

# %%
import xgboost as xgb
model = xgb.XGBRegressor(eval_metric= 'rmse')
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
import optuna

def objective(trial):
    params = {
        'objective': 'reg:squarederror',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10)

    }

    xgb_model = xgb.XGBRegressor(**params)
    xgb_model.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False
    )
    y_pred = xgb_model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=500)
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-07-30 12:15:56,097] A new study created in memory with name: no-name-149d3f90-4cd7-4f8d-8468-e9c43e555691
# [I 2024-07-30 12:15:56,276] Trial 0 finished with value: 20.11409846506419 and parameters: {'learning_rate': 0.1936200475298816, 'max_depth': 4, 'n_estimators': 136, 'colsample_bytree': 0.5945256361122702, 'subsample': 0.871001443885298, 'scale_pos_weight': 4.0599604579151976}. Best is trial 0 with value: 20.11409846506419.
# [I 2024-07-30 12:15:56,395] Trial 1 finished with value: 19.946235553460205 and parameters: {'learning_rate': 0.04293254448282202, 'max_depth': 7, 'n_estimators': 50, 'colsample_bytree': 0.6658979409919759, 'subsample': 0.834422185125615, 'scale_pos_weight': 6.0732827794720725}. Best is trial 1 with value: 19.946235553460205.
# [I 2024-07-30 12:15:56,698] Trial 2 finished with value: 16.74187826687289 and parameters: {'learning_rate': 0.19135198449675178, 'max_depth': 8, 'n_estimators': 146, 'colsample_bytree': 0.7147255694155832, 'subsample': 0.5164627221382299, 'scale_pos_weight': 1.642747847208613}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:15:57,169] Trial 3 finished with value: 18.409021840917934 and parameters: {'learning_rate': 0.1817944254079784, 'max_depth': 8, 'n_estimators': 111, 'colsample_bytree': 0.63224584096745, 'subsample': 0.9214669817762633, 'scale_pos_weight': 3.1157695806096055}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:15:57,735] Trial 4 finished with value: 20.599186606970598 and parameters: {'learning_rate': 0.15606024255731268, 'max_depth': 8, 'n_estimators': 144, 'colsample_bytree': 0.9970877792947036, 'subsample': 0.8993713899505734, 'scale_pos_weight': 9.040423548838547}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:15:58,465] Trial 5 finished with value: 17.253800839414552 and parameters: {'learning_rate': 0.16988014877324767, 'max_depth': 8, 'n_estimators': 168, 'colsample_bytree': 0.8044753596502295, 'subsample': 0.9896368622098517, 'scale_pos_weight': 4.405095227790803}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:15:58,564] Trial 6 finished with value: 21.11519101234418 and parameters: {'learning_rate': 0.17455208926393026, 'max_depth': 4, 'n_estimators': 67, 'colsample_bytree': 0.6674534501288846, 'subsample': 0.5711855412670652, 'scale_pos_weight': 3.656384178337777}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:16:04,079] Trial 7 finished with value: 17.58136814302026 and parameters: {'learning_rate': 0.09813827562299086, 'max_depth': 9, 'n_estimators': 200, 'colsample_bytree': 0.6021370037829665, 'subsample': 0.9144146182507953, 'scale_pos_weight': 9.590361439196842}. Best is trial 2 with value: 16.74187826687289.
# [I 2024-07-30 12:18:21,055] Trial 132 finished with value: 15.042173000630415 and parameters: {'learning_rate': 0.02867977461166666, 'max_depth': 10, 'n_estimators': 167, 'colsample_bytree': 0.8273827930333788, 'subsample': 0.5126702442745552, 'scale_pos_weight': 3.8296651594254647}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:21,598] Trial 133 finished with value: 15.657371815389752 and parameters: {'learning_rate': 0.028485603090230283, 'max_depth': 9, 'n_estimators': 171, 'colsample_bytree': 0.8216320740667635, 'subsample': 0.5413682766851468, 'scale_pos_weight': 3.9242576189470446}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:22,140] Trial 134 finished with value: 15.26144356398255 and parameters: {'learning_rate': 0.03360433482589474, 'max_depth': 10, 'n_estimators': 148, 'colsample_bytree': 0.8442760531153712, 'subsample': 0.5288918734882532, 'scale_pos_weight': 3.2143300122816325}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:22,713] Trial 135 finished with value: 14.736662431413555 and parameters: {'learning_rate': 0.02993383369192677, 'max_depth': 10, 'n_estimators': 157, 'colsample_bytree': 0.8262870124798682, 'subsample': 0.5176051501325994, 'scale_pos_weight': 4.34055132201385}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:23,306] Trial 136 finished with value: 15.398623973241591 and parameters: {'learning_rate': 0.02012200612151501, 'max_depth': 10, 'n_estimators': 158, 'colsample_bytree': 0.8314792496620892, 'subsample': 0.5288489021152706, 'scale_pos_weight': 4.164053989319224}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:23,908] Trial 137 finished with value: 14.871577946418437 and parameters: {'learning_rate': 0.03206394807609315, 'max_depth': 10, 'n_estimators': 153, 'colsample_bytree': 0.8251937290676963, 'subsample': 0.5001964917679284, 'scale_pos_weight': 3.6711052805518545}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:24,425] Trial 138 finished with value: 15.22558219663541 and parameters: {'learning_rate': 0.025238647095680272, 'max_depth': 9, 'n_estimators': 154, 'colsample_bytree': 0.837326914805558, 'subsample': 0.5072271446625031, 'scale_pos_weight': 2.779807219689676}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:24,992] Trial 139 finished with value: 16.84464233373501 and parameters: {'learning_rate': 0.016857288875055103, 'max_depth': 10, 'n_estimators': 150, 'colsample_bytree': 0.8244779016408682, 'subsample': 0.5183781878908003, 'scale_pos_weight': 2.9782405472125832}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:25,714] Trial 140 finished with value: 15.459731023575042 and parameters: {'learning_rate': 0.030625289488019545, 'max_depth': 10, 'n_estimators': 164, 'colsample_bytree': 0.8795706615790095, 'subsample': 0.7249006124615365, 'scale_pos_weight': 3.633887358166797}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:26,181] Trial 141 finished with value: 14.722806405729408 and parameters: {'learning_rate': 0.035932774587770035, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8501952387193219, 'subsample': 0.5002638499485779, 'scale_pos_weight': 3.4258395234181354}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:26,655] Trial 142 finished with value: 14.7309701885222 and parameters: {'learning_rate': 0.043843039745743106, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8491810394992787, 'subsample': 0.5118737159197018, 'scale_pos_weight': 3.4386357810657757}. Best is trial 130 with value: 14.69962281524854.
# [I 2024-07-30 12:18:27,342] Trial 143 finished with value: 14.433261490324654 and parameters: {'learning_rate': 0.04501575548094406, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8615423773245974, 'subsample': 0.5015531654783725, 'scale_pos_weight': 3.505434454708047}. Best is trial 143 with value: 14.433261490324654.
# ...
# [I 2024-07-30 12:21:44,685] Trial 453 finished with value: 15.448250363587524 and parameters: {'learning_rate': 0.04452020702549169, 'max_depth': 10, 'n_estimators': 121, 'colsample_bytree': 0.8911903687346142, 'subsample': 0.5090600227259302, 'scale_pos_weight': 1.4445521009102007}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:44,951] Trial 454 finished with value: 16.293923876146092 and parameters: {'learning_rate': 0.036055120215572764, 'max_depth': 6, 'n_estimators': 131, 'colsample_bytree': 0.8847657334710817, 'subsample': 0.536877234115961, 'scale_pos_weight': 1.282044569347229}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:45,455] Trial 455 finished with value: 15.55919170040116 and parameters: {'learning_rate': 0.0404650904991876, 'max_depth': 10, 'n_estimators': 125, 'colsample_bytree': 0.8974962189082331, 'subsample': 0.5005636090944179, 'scale_pos_weight': 1.3684486248334982}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:45,893] Trial 456 finished with value: 15.50254376781849 and parameters: {'learning_rate': 0.08085964195267237, 'max_depth': 10, 'n_estimators': 135, 'colsample_bytree': 0.8793787954663673, 'subsample': 0.5183360374366163, 'scale_pos_weight': 1.625096523282375}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:46,411] Trial 457 finished with value: 15.453146687130255 and parameters: {'learning_rate': 0.04657288639191343, 'max_depth': 10, 'n_estimators': 130, 'colsample_bytree': 0.9154647481182845, 'subsample': 0.5494280418429578, 'scale_pos_weight': 1.3419744396948292}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:46,828] Trial 458 finished with value: 16.610425739311772 and parameters: {'learning_rate': 0.11312307400948017, 'max_depth': 10, 'n_estimators': 123, 'colsample_bytree': 0.8629620651157507, 'subsample': 0.5000908708461415, 'scale_pos_weight': 1.8769259812016328}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:47,050] Trial 459 finished with value: 17.868468542987937 and parameters: {'learning_rate': 0.04382102323947804, 'max_depth': 5, 'n_estimators': 115, 'colsample_bytree': 0.8897519708023053, 'subsample': 0.5251509730491888, 'scale_pos_weight': 1.5214568091254292}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:47,611] Trial 460 finished with value: 15.725047094130998 and parameters: {'learning_rate': 0.037359756235051736, 'max_depth': 10, 'n_estimators': 127, 'colsample_bytree': 0.874598438537671, 'subsample': 0.7779115500494593, 'scale_pos_weight': 1.8515168003377094}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:48,076] Trial 461 finished with value: 14.968410787411582 and parameters: {'learning_rate': 0.03033006787095985, 'max_depth': 10, 'n_estimators': 119, 'colsample_bytree': 0.8686126829331424, 'subsample': 0.5104558967521422, 'scale_pos_weight': 1.596495361508341}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:48,421] Trial 462 finished with value: 17.11408066610873 and parameters: {'learning_rate': 0.051003366968701634, 'max_depth': 10, 'n_estimators': 61, 'colsample_bytree': 0.9037648942034942, 'subsample': 0.5131657050724541, 'scale_pos_weight': 2.6116761658410566}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:48,906] Trial 463 finished with value: 15.121449552346423 and parameters: {'learning_rate': 0.04756613148051524, 'max_depth': 10, 'n_estimators': 133, 'colsample_bytree': 0.8825470489831186, 'subsample': 0.5226909081449548, 'scale_pos_weight': 1.933170477492288}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:49,405] Trial 464 finished with value: 14.681942627218488 and parameters: {'learning_rate': 0.04201347766423325, 'max_depth': 10, 'n_estimators': 129, 'colsample_bytree': 0.8588053487945773, 'subsample': 0.5093092446269505, 'scale_pos_weight': 3.946278359984706}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:49,938] Trial 465 finished with value: 16.424737623940317 and parameters: {'learning_rate': 0.039399482193042075, 'max_depth': 10, 'n_estimators': 136, 'colsample_bytree': 0.8677317492062512, 'subsample': 0.6271945346807997, 'scale_pos_weight': 1.2194520871184755}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:50,448] Trial 466 finished with value: 16.832927055422473 and parameters: {'learning_rate': 0.05374861911118556, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8928162004535595, 'subsample': 0.5345875987136345, 'scale_pos_weight': 2.7548706727358807}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:50,912] Trial 467 finished with value: 15.19125801713118 and parameters: {'learning_rate': 0.04539551782294279, 'max_depth': 10, 'n_estimators': 125, 'colsample_bytree': 0.8786578064370656, 'subsample': 0.5170859951684251, 'scale_pos_weight': 3.416295111098865}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:51,406] Trial 468 finished with value: 15.130091719666503 and parameters: {'learning_rate': 0.03404310649659813, 'max_depth': 10, 'n_estimators': 122, 'colsample_bytree': 0.8406876895896289, 'subsample': 0.5003455933689125, 'scale_pos_weight': 2.5145952992711336}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:53,059] Trial 469 finished with value: 14.874019332939927 and parameters: {'learning_rate': 0.04283411859130578, 'max_depth': 10, 'n_estimators': 128, 'colsample_bytree': 0.8555892060060285, 'subsample': 0.5086800663180949, 'scale_pos_weight': 1.72102152428032}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:56,143] Trial 470 finished with value: 14.822337089711418 and parameters: {'learning_rate': 0.047719319606031076, 'max_depth': 10, 'n_estimators': 134, 'colsample_bytree': 0.867633430064164, 'subsample': 0.5230171244073948, 'scale_pos_weight': 2.154408227327336}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:56,619] Trial 471 finished with value: 14.959591472907572 and parameters: {'learning_rate': 0.037926984041011726, 'max_depth': 10, 'n_estimators': 125, 'colsample_bytree': 0.8857037637004913, 'subsample': 0.5341306780883268, 'scale_pos_weight': 2.943948668341066}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:57,137] Trial 472 finished with value: 14.916052920019432 and parameters: {'learning_rate': 0.04986365966275223, 'max_depth': 10, 'n_estimators': 130, 'colsample_bytree': 0.8767121463938179, 'subsample': 0.5002072621176193, 'scale_pos_weight': 2.318036846303505}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:57,655] Trial 473 finished with value: 14.907689626319755 and parameters: {'learning_rate': 0.04181184746412035, 'max_depth': 10, 'n_estimators': 137, 'colsample_bytree': 0.6787974213336134, 'subsample': 0.5152872282525155, 'scale_pos_weight': 2.711590547569014}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:58,243] Trial 474 finished with value: 15.343032088889233 and parameters: {'learning_rate': 0.02582006488522657, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8512593918798944, 'subsample': 0.5092011290742718, 'scale_pos_weight': 2.0009202499107834}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:58,806] Trial 475 finished with value: 15.719344769098287 and parameters: {'learning_rate': 0.04399154321834576, 'max_depth': 10, 'n_estimators': 112, 'colsample_bytree': 0.8615083974948274, 'subsample': 0.7397305065203337, 'scale_pos_weight': 3.1770903173721803}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:59,371] Trial 476 finished with value: 16.17748962756141 and parameters: {'learning_rate': 0.03635727666320888, 'max_depth': 10, 'n_estimators': 101, 'colsample_bytree': 0.9000892558135667, 'subsample': 0.6754539375284391, 'scale_pos_weight': 1.4077547353600184}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:21:59,824] Trial 477 finished with value: 15.156859630321778 and parameters: {'learning_rate': 0.05653354032693682, 'max_depth': 10, 'n_estimators': 120, 'colsample_bytree': 0.8327713604042511, 'subsample': 0.5229260991593776, 'scale_pos_weight': 2.5038303128498587}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:00,266] Trial 478 finished with value: 17.561015873209325 and parameters: {'learning_rate': 0.1390461745386974, 'max_depth': 10, 'n_estimators': 127, 'colsample_bytree': 0.8736821016148159, 'subsample': 0.5159740596489124, 'scale_pos_weight': 3.7947943640157025}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:00,679] Trial 479 finished with value: 15.055693585352985 and parameters: {'learning_rate': 0.04694533389366641, 'max_depth': 10, 'n_estimators': 90, 'colsample_bytree': 0.8630541190698944, 'subsample': 0.5296528146534596, 'scale_pos_weight': 2.8426610281101095}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:01,304] Trial 480 finished with value: 15.624503749947337 and parameters: {'learning_rate': 0.03154707886311024, 'max_depth': 10, 'n_estimators': 134, 'colsample_bytree': 0.8893034331164682, 'subsample': 0.5462913272862243, 'scale_pos_weight': 3.2466616124625247}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:01,738] Trial 481 finished with value: 15.876900938187841 and parameters: {'learning_rate': 0.0394064939095838, 'max_depth': 10, 'n_estimators': 130, 'colsample_bytree': 0.5499133188579475, 'subsample': 0.5085629658966232, 'scale_pos_weight': 1.0062147419196446}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:02,278] Trial 482 finished with value: 16.503946286817747 and parameters: {'learning_rate': 0.05264867563041721, 'max_depth': 10, 'n_estimators': 123, 'colsample_bytree': 0.9090397932439644, 'subsample': 0.5085790237190384, 'scale_pos_weight': 1.631548135609253}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:02,551] Trial 483 finished with value: 18.160265690994915 and parameters: {'learning_rate': 0.04386020160306916, 'max_depth': 10, 'n_estimators': 50, 'colsample_bytree': 0.881424987546894, 'subsample': 0.5233694769592648, 'scale_pos_weight': 3.5517814588012993}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:03,156] Trial 484 finished with value: 17.090475500376655 and parameters: {'learning_rate': 0.04947184162724304, 'max_depth': 10, 'n_estimators': 139, 'colsample_bytree': 0.8441868724630622, 'subsample': 0.8439107754280156, 'scale_pos_weight': 2.3694331382330422}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:03,662] Trial 485 finished with value: 15.398546320795106 and parameters: {'learning_rate': 0.04007043617963124, 'max_depth': 10, 'n_estimators': 126, 'colsample_bytree': 0.9310178860572584, 'subsample': 0.5002154976044049, 'scale_pos_weight': 2.144746423876789}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:04,076] Trial 486 finished with value: 15.726359085613025 and parameters: {'learning_rate': 0.03553123738081277, 'max_depth': 10, 'n_estimators': 83, 'colsample_bytree': 0.8551539666232573, 'subsample': 0.5167100887730429, 'scale_pos_weight': 3.040304479719345}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:04,613] Trial 487 finished with value: 15.545357055971701 and parameters: {'learning_rate': 0.04513890845793636, 'max_depth': 10, 'n_estimators': 132, 'colsample_bytree': 0.8691435160068435, 'subsample': 0.5827338158346627, 'scale_pos_weight': 2.6677805199443725}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:05,160] Trial 488 finished with value: 15.373101323275773 and parameters: {'learning_rate': 0.040434783982038494, 'max_depth': 10, 'n_estimators': 129, 'colsample_bytree': 0.8183602686180567, 'subsample': 0.5386020519095934, 'scale_pos_weight': 9.98757055501354}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:05,703] Trial 489 finished with value: 15.881339373650071 and parameters: {'learning_rate': 0.04885627085374151, 'max_depth': 10, 'n_estimators': 136, 'colsample_bytree': 0.8891664579794497, 'subsample': 0.5082689970247907, 'scale_pos_weight': 1.927672523466598}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:06,372] Trial 490 finished with value: 15.495091166114019 and parameters: {'learning_rate': 0.062124973101523887, 'max_depth': 10, 'n_estimators': 117, 'colsample_bytree': 0.8759510641780034, 'subsample': 0.525550002831254, 'scale_pos_weight': 3.3215502683396414}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:09,484] Trial 491 finished with value: 14.431062936769228 and parameters: {'learning_rate': 0.043648629248875616, 'max_depth': 10, 'n_estimators': 123, 'colsample_bytree': 0.8580595287804813, 'subsample': 0.5160083990871063, 'scale_pos_weight': 2.9130950908776474}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:11,223] Trial 492 finished with value: 14.882515439993918 and parameters: {'learning_rate': 0.05300248247502738, 'max_depth': 10, 'n_estimators': 123, 'colsample_bytree': 0.8391140691584511, 'subsample': 0.5002781488451972, 'scale_pos_weight': 2.858546512457638}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:11,692] Trial 493 finished with value: 14.720821641302038 and parameters: {'learning_rate': 0.04552664475789935, 'max_depth': 10, 'n_estimators': 119, 'colsample_bytree': 0.86932858156014, 'subsample': 0.5572246134552525, 'scale_pos_weight': 3.0724501186987405}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:12,171] Trial 494 finished with value: 16.136417210998466 and parameters: {'learning_rate': 0.04877030435552838, 'max_depth': 10, 'n_estimators': 122, 'colsample_bytree': 0.8966322509440244, 'subsample': 0.5320554007957116, 'scale_pos_weight': 2.953510392821423}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:12,712] Trial 495 finished with value: 14.548773403473188 and parameters: {'learning_rate': 0.043481117433998975, 'max_depth': 10, 'n_estimators': 125, 'colsample_bytree': 0.8830503311026277, 'subsample': 0.5169353693833949, 'scale_pos_weight': 3.4492305187999026}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:13,127] Trial 496 finished with value: 16.12728127575431 and parameters: {'learning_rate': 0.10386818169622128, 'max_depth': 10, 'n_estimators': 127, 'colsample_bytree': 0.6665613916481, 'subsample': 0.507444360586132, 'scale_pos_weight': 3.1384037847125725}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:13,630] Trial 497 finished with value: 14.718953436600055 and parameters: {'learning_rate': 0.0421654107267232, 'max_depth': 10, 'n_estimators': 119, 'colsample_bytree': 0.849533362058872, 'subsample': 0.5259565337546329, 'scale_pos_weight': 2.7110482177942177}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:14,098] Trial 498 finished with value: 17.776167663826623 and parameters: {'learning_rate': 0.06778028894057371, 'max_depth': 10, 'n_estimators': 114, 'colsample_bytree': 0.9495161728220767, 'subsample': 0.6512494901580341, 'scale_pos_weight': 2.884050258475596}. Best is trial 222 with value: 14.155797089550832.
# [I 2024-07-30 12:22:14,579] Trial 499 finished with value: 15.19328453291326 and parameters: {'learning_rate': 0.0459922284201821, 'max_depth': 10, 'n_estimators': 125, 'colsample_bytree': 0.8610791237433435, 'subsample': 0.5100003065137981, 'scale_pos_weight': 3.1893586206152142}. Best is trial 222 with value: 14.155797089550832.
# Best hyperparameters:  {'learning_rate': 0.04284189640550591, 'max_depth': 10, 'n_estimators': 126, 'colsample_bytree': 0.8698605137266143, 'subsample': 0.5177425463557167, 'scale_pos_weight': 3.28936797786666}

# %%
model = xgb.XGBRegressor(eval_metric= 'rmse', **study.best_params)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"XGBoost - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# XGBoost - MAE: 1.5520885560868982, RMSE: 3.7624190475744235, R²: 0.8867402813981602

# %% [markdown]
# #Building an ann model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')

model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.2, verbose=2)

y_pred = model.predict(X_test).flatten()
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"ANN - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# Epoch 1/100
# 362/362 - 2s - loss: 40.1076 - val_loss: 23.5728 - 2s/epoch - 5ms/step
# Epoch 2/100
# 362/362 - 1s - loss: 27.9252 - val_loss: 30.0963 - 1s/epoch - 3ms/step
# Epoch 3/100
# 362/362 - 1s - loss: 25.8421 - val_loss: 20.8706 - 1s/epoch - 3ms/step
# Epoch 4/100
# 362/362 - 1s - loss: 25.1364 - val_loss: 19.1370 - 997ms/epoch - 3ms/step
# Epoch 5/100
# 362/362 - 1s - loss: 24.3710 - val_loss: 21.6323 - 709ms/epoch - 2ms/step
# Epoch 6/100
# 362/362 - 1s - loss: 25.5052 - val_loss: 16.8467 - 650ms/epoch - 2ms/step
# Epoch 7/100
# 362/362 - 1s - loss: 22.1399 - val_loss: 19.4866 - 640ms/epoch - 2ms/step
# Epoch 8/100
# 362/362 - 1s - loss: 22.9889 - val_loss: 20.0629 - 682ms/epoch - 2ms/step
# Epoch 9/100
# 362/362 - 1s - loss: 24.6118 - val_loss: 17.1102 - 648ms/epoch - 2ms/step
# Epoch 10/100
# 362/362 - 1s - loss: 22.8370 - val_loss: 21.8942 - 639ms/epoch - 2ms/step
# Epoch 11/100
# 362/362 - 1s - loss: 21.8813 - val_loss: 18.5365 - 657ms/epoch - 2ms/step
# Epoch 12/100
# 362/362 - 1s - loss: 21.9484 - val_loss: 34.2136 - 682ms/epoch - 2ms/step
# Epoch 13/100
# 362/362 - 1s - loss: 28.3762 - val_loss: 18.6985 - 647ms/epoch - 2ms/step
# Epoch 14/100
# 362/362 - 1s - loss: 23.0582 - val_loss: 23.1219 - 672ms/epoch - 2ms/step
# Epoch 15/100
# 362/362 - 1s - loss: 21.6187 - val_loss: 17.1037 - 699ms/epoch - 2ms/step
# Epoch 16/100
# 362/362 - 1s - loss: 20.8843 - val_loss: 26.7474 - 673ms/epoch - 2ms/step
# Epoch 17/100
# 362/362 - 1s - loss: 20.3390 - val_loss: 19.5763 - 695ms/epoch - 2ms/step
# Epoch 18/100
# 362/362 - 1s - loss: 21.3702 - val_loss: 17.6142 - 698ms/epoch - 2ms/step
# Epoch 19/100
# 362/362 - 1s - loss: 20.5501 - val_loss: 16.0125 - 674ms/epoch - 2ms/step
# Epoch 20/100
# 362/362 - 1s - loss: 18.8821 - val_loss: 20.2901 - 928ms/epoch - 3ms/step
# Epoch 21/100
# 362/362 - 1s - loss: 19.1885 - val_loss: 26.4383 - 1s/epoch - 3ms/step
# Epoch 22/100
# 362/362 - 1s - loss: 21.0052 - val_loss: 20.6953 - 1s/epoch - 3ms/step
# Epoch 23/100
# 362/362 - 1s - loss: 19.5797 - val_loss: 18.4320 - 1s/epoch - 3ms/step
# Epoch 24/100
# 362/362 - 1s - loss: 19.5354 - val_loss: 17.1578 - 880ms/epoch - 2ms/step
# Epoch 25/100
# 362/362 - 1s - loss: 20.1455 - val_loss: 18.6745 - 685ms/epoch - 2ms/step
# Epoch 26/100
# 362/362 - 1s - loss: 19.3086 - val_loss: 16.6999 - 665ms/epoch - 2ms/step
# Epoch 27/100
# 362/362 - 1s - loss: 18.8169 - val_loss: 17.5465 - 655ms/epoch - 2ms/step
# Epoch 28/100
# 362/362 - 1s - loss: 19.3775 - val_loss: 19.8789 - 684ms/epoch - 2ms/step
# Epoch 29/100
# 362/362 - 1s - loss: 18.7199 - val_loss: 19.2022 - 693ms/epoch - 2ms/step
# Epoch 30/100
# 362/362 - 1s - loss: 18.2602 - val_loss: 19.7770 - 637ms/epoch - 2ms/step
# Epoch 31/100
# 362/362 - 1s - loss: 19.5325 - val_loss: 21.3981 - 654ms/epoch - 2ms/step
# Epoch 32/100
# 362/362 - 1s - loss: 18.4595 - val_loss: 16.7924 - 739ms/epoch - 2ms/step
# Epoch 33/100
# 362/362 - 1s - loss: 19.1638 - val_loss: 16.5546 - 702ms/epoch - 2ms/step
# Epoch 34/100
# 362/362 - 1s - loss: 17.7817 - val_loss: 20.5822 - 651ms/epoch - 2ms/step
# Epoch 35/100
# 362/362 - 1s - loss: 19.1352 - val_loss: 19.9221 - 691ms/epoch - 2ms/step
# Epoch 36/100
# 362/362 - 1s - loss: 17.2700 - val_loss: 18.8514 - 630ms/epoch - 2ms/step
# Epoch 37/100
# 362/362 - 1s - loss: 17.0115 - val_loss: 19.8150 - 688ms/epoch - 2ms/step
# Epoch 38/100
# 362/362 - 1s - loss: 18.2233 - val_loss: 17.9810 - 645ms/epoch - 2ms/step
# Epoch 39/100
# 362/362 - 1s - loss: 18.1321 - val_loss: 17.8639 - 741ms/epoch - 2ms/step
# Epoch 40/100
# 362/362 - 1s - loss: 17.3825 - val_loss: 21.5355 - 1s/epoch - 3ms/step
# Epoch 41/100
# 362/362 - 2s - loss: 18.8917 - val_loss: 17.3330 - 2s/epoch - 7ms/step
# Epoch 42/100
# 362/362 - 2s - loss: 16.5255 - val_loss: 20.0223 - 2s/epoch - 7ms/step
# Epoch 43/100
# 362/362 - 2s - loss: 16.9341 - val_loss: 16.0499 - 2s/epoch - 5ms/step
# Epoch 44/100
# 362/362 - 2s - loss: 17.3804 - val_loss: 18.3555 - 2s/epoch - 6ms/step
# Epoch 45/100
# 362/362 - 2s - loss: 15.8061 - val_loss: 17.8268 - 2s/epoch - 5ms/step
# Epoch 46/100
# 362/362 - 1s - loss: 17.2485 - val_loss: 16.5733 - 1s/epoch - 3ms/step
# Epoch 47/100
# 362/362 - 2s - loss: 17.0449 - val_loss: 17.0872 - 2s/epoch - 7ms/step
# Epoch 48/100
# 362/362 - 3s - loss: 16.4409 - val_loss: 16.9387 - 3s/epoch - 8ms/step
# Epoch 49/100
# 362/362 - 2s - loss: 15.6823 - val_loss: 21.9596 - 2s/epoch - 5ms/step
# Epoch 50/100
# 362/362 - 1s - loss: 16.9955 - val_loss: 17.9542 - 1s/epoch - 3ms/step
# Epoch 51/100
# 362/362 - 1s - loss: 17.2092 - val_loss: 16.5469 - 672ms/epoch - 2ms/step
# Epoch 52/100
# 362/362 - 1s - loss: 16.7807 - val_loss: 18.3980 - 640ms/epoch - 2ms/step
# Epoch 53/100
# 362/362 - 1s - loss: 17.0271 - val_loss: 17.0593 - 692ms/epoch - 2ms/step
# Epoch 54/100
# 362/362 - 1s - loss: 16.5792 - val_loss: 20.3264 - 670ms/epoch - 2ms/step
# Epoch 55/100
# 362/362 - 1s - loss: 16.6211 - val_loss: 17.1184 - 649ms/epoch - 2ms/step
# Epoch 56/100
# 362/362 - 1s - loss: 16.4659 - val_loss: 22.2065 - 646ms/epoch - 2ms/step
# Epoch 57/100
# 362/362 - 1s - loss: 17.5944 - val_loss: 16.9962 - 684ms/epoch - 2ms/step
# Epoch 58/100
# 362/362 - 1s - loss: 15.3695 - val_loss: 17.0551 - 647ms/epoch - 2ms/step
# Epoch 59/100
# 362/362 - 1s - loss: 16.1265 - val_loss: 19.5455 - 638ms/epoch - 2ms/step
# Epoch 60/100
# 362/362 - 1s - loss: 16.2157 - val_loss: 17.9950 - 631ms/epoch - 2ms/step
# Epoch 61/100
# 362/362 - 1s - loss: 16.7674 - val_loss: 18.9372 - 684ms/epoch - 2ms/step
# Epoch 62/100
# 362/362 - 1s - loss: 16.0563 - val_loss: 19.2714 - 684ms/epoch - 2ms/step
# Epoch 63/100
# 362/362 - 1s - loss: 16.3096 - val_loss: 19.1876 - 672ms/epoch - 2ms/step
# Epoch 64/100
# 362/362 - 1s - loss: 15.3597 - val_loss: 22.8353 - 649ms/epoch - 2ms/step
# Epoch 65/100
# 362/362 - 1s - loss: 16.9710 - val_loss: 16.7895 - 851ms/epoch - 2ms/step
# Epoch 66/100
# 362/362 - 1s - loss: 15.5003 - val_loss: 17.2346 - 1s/epoch - 3ms/step
# Epoch 67/100
# 362/362 - 1s - loss: 17.4490 - val_loss: 22.7185 - 1s/epoch - 3ms/step
# Epoch 68/100
# 362/362 - 1s - loss: 15.3390 - val_loss: 17.2452 - 977ms/epoch - 3ms/step
# Epoch 69/100
# 362/362 - 1s - loss: 14.2917 - val_loss: 18.2159 - 1s/epoch - 3ms/step
# Epoch 70/100
# 362/362 - 1s - loss: 15.1615 - val_loss: 18.4710 - 642ms/epoch - 2ms/step
# Epoch 71/100
# 362/362 - 1s - loss: 15.1421 - val_loss: 20.0892 - 644ms/epoch - 2ms/step
# Epoch 72/100
# 362/362 - 1s - loss: 15.8787 - val_loss: 21.6243 - 643ms/epoch - 2ms/step
# Epoch 73/100
# 362/362 - 1s - loss: 15.7519 - val_loss: 19.9064 - 654ms/epoch - 2ms/step
# Epoch 74/100
# 362/362 - 1s - loss: 16.1173 - val_loss: 18.6364 - 679ms/epoch - 2ms/step
# Epoch 75/100
# 362/362 - 1s - loss: 14.9765 - val_loss: 25.0411 - 688ms/epoch - 2ms/step
# Epoch 76/100
# 362/362 - 1s - loss: 15.4244 - val_loss: 18.8979 - 639ms/epoch - 2ms/step
# Epoch 77/100
# 362/362 - 1s - loss: 15.4408 - val_loss: 20.1202 - 646ms/epoch - 2ms/step
# Epoch 78/100
# 362/362 - 1s - loss: 14.7224 - val_loss: 18.9874 - 667ms/epoch - 2ms/step
# Epoch 79/100
# 362/362 - 1s - loss: 15.2717 - val_loss: 21.0064 - 681ms/epoch - 2ms/step
# Epoch 80/100
# 362/362 - 1s - loss: 14.4774 - val_loss: 23.7379 - 651ms/epoch - 2ms/step
# Epoch 81/100
# 362/362 - 1s - loss: 15.8010 - val_loss: 21.0020 - 647ms/epoch - 2ms/step
# Epoch 82/100
# 362/362 - 1s - loss: 14.9506 - val_loss: 18.8661 - 676ms/epoch - 2ms/step
# Epoch 83/100
# 362/362 - 1s - loss: 14.4978 - val_loss: 19.9181 - 683ms/epoch - 2ms/step
# Epoch 84/100
# 362/362 - 1s - loss: 14.4919 - val_loss: 21.5339 - 628ms/epoch - 2ms/step
# Epoch 85/100
# 362/362 - 1s - loss: 14.4287 - val_loss: 20.3225 - 1s/epoch - 3ms/step
# Epoch 86/100
# 362/362 - 1s - loss: 14.0831 - val_loss: 25.1400 - 1s/epoch - 3ms/step
# Epoch 87/100
# 362/362 - 1s - loss: 14.4011 - val_loss: 20.0129 - 928ms/epoch - 3ms/step
# Epoch 88/100
# 362/362 - 1s - loss: 14.8191 - val_loss: 19.1036 - 1s/epoch - 3ms/step
# Epoch 89/100
# 362/362 - 1s - loss: 14.6425 - val_loss: 23.8675 - 728ms/epoch - 2ms/step
# Epoch 90/100
# 362/362 - 1s - loss: 15.6508 - val_loss: 20.2162 - 642ms/epoch - 2ms/step
# Epoch 91/100
# 362/362 - 1s - loss: 13.6229 - val_loss: 24.7197 - 627ms/epoch - 2ms/step
# Epoch 92/100
# 362/362 - 1s - loss: 13.2705 - val_loss: 20.4987 - 651ms/epoch - 2ms/step
# Epoch 93/100
# 362/362 - 1s - loss: 14.1010 - val_loss: 23.1070 - 642ms/epoch - 2ms/step
# Epoch 94/100
# 362/362 - 1s - loss: 13.4315 - val_loss: 19.3157 - 617ms/epoch - 2ms/step
# Epoch 95/100
# 362/362 - 1s - loss: 13.3184 - val_loss: 21.7517 - 646ms/epoch - 2ms/step
# Epoch 96/100
# 362/362 - 1s - loss: 14.2723 - val_loss: 21.0060 - 646ms/epoch - 2ms/step
# Epoch 97/100
# 362/362 - 1s - loss: 13.4831 - val_loss: 26.3531 - 625ms/epoch - 2ms/step
# Epoch 98/100
# 362/362 - 1s - loss: 14.1660 - val_loss: 27.1769 - 676ms/epoch - 2ms/step
# Epoch 99/100
# 362/362 - 1s - loss: 15.4667 - val_loss: 20.3826 - 642ms/epoch - 2ms/step
# Epoch 100/100
# 362/362 - 1s - loss: 16.7050 - val_loss: 22.3369 - 632ms/epoch - 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# ANN - MAE: 2.4486479829680485, RMSE: 5.515134363562374, R²: 0.7566376757681411

# %%
# !pip install keras-tuner

import keras
from keras import layers
from keras_tuner import RandomSearch

def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units1', min_value=32, max_value=128, step=32), activation='relu', input_dim=X_train.shape[1]))
    model.add(Dense(units=hp.Int('units2', min_value=16, max_value=64, step=16), activation='relu'))
    model.add(Dense(1))

    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-1, sampling='LOG')),
        loss='mean_squared_error'
    )
    return model

tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir',
    project_name='intro_to_kt'
)

tuner.search(X_train, y_train, epochs=100, validation_split=0.2)

best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# Trial 10 Complete [00h 00m 43s]
# val_loss: 16.421184539794922
#
# Best val_loss So Far: 14.549753189086914
# Total elapsed time: 00h 06m 06s
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 96)                960
#
#  dense_1 (Dense)             (None, 48)                4656
#
#  dense_2 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 5665 (22.13 KB)
# Trainable params: 5665 (22.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
best_model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.2, verbose=2)

y_pred = best_model.predict(X_test).flatten()
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"ANN - MAE: {mae}, RMSE: {rmse}, R²: {r2}")
# Out:
# Epoch 1/100
# 362/362 - 3s - loss: 18.7117 - val_loss: 26.7424 - 3s/epoch - 7ms/step
# Epoch 2/100
# 362/362 - 2s - loss: 19.0846 - val_loss: 43.8406 - 2s/epoch - 6ms/step
# Epoch 3/100
# 362/362 - 2s - loss: 20.2149 - val_loss: 19.2248 - 2s/epoch - 7ms/step
# Epoch 4/100
# 362/362 - 1s - loss: 17.8889 - val_loss: 16.6487 - 1s/epoch - 3ms/step
# Epoch 5/100
# 362/362 - 1s - loss: 16.8199 - val_loss: 15.3411 - 1s/epoch - 4ms/step
# Epoch 6/100
# 362/362 - 3s - loss: 16.8236 - val_loss: 16.7463 - 3s/epoch - 8ms/step
# Epoch 7/100
# 362/362 - 1s - loss: 16.4457 - val_loss: 17.0408 - 1s/epoch - 4ms/step
# Epoch 8/100
# 362/362 - 1s - loss: 16.9658 - val_loss: 15.1745 - 1s/epoch - 4ms/step
# Epoch 9/100
# 362/362 - 1s - loss: 16.6627 - val_loss: 18.4689 - 1s/epoch - 4ms/step
# Epoch 10/100
# 362/362 - 4s - loss: 17.0136 - val_loss: 16.3303 - 4s/epoch - 11ms/step
# Epoch 11/100
# 362/362 - 3s - loss: 16.7120 - val_loss: 16.5723 - 3s/epoch - 7ms/step
# Epoch 12/100
# 362/362 - 2s - loss: 16.3653 - val_loss: 14.8038 - 2s/epoch - 6ms/step
# Epoch 13/100
# 362/362 - 1s - loss: 15.9523 - val_loss: 16.8889 - 1s/epoch - 3ms/step
# Epoch 14/100
# 362/362 - 2s - loss: 15.4767 - val_loss: 14.8814 - 2s/epoch - 4ms/step
# Epoch 15/100
# 362/362 - 1s - loss: 16.5998 - val_loss: 18.3792 - 1s/epoch - 4ms/step
# Epoch 16/100
# 362/362 - 2s - loss: 16.0858 - val_loss: 14.6692 - 2s/epoch - 5ms/step
# Epoch 17/100
# 362/362 - 1s - loss: 15.8082 - val_loss: 16.0302 - 1s/epoch - 4ms/step
# Epoch 18/100
# 362/362 - 2s - loss: 16.1550 - val_loss: 16.7306 - 2s/epoch - 4ms/step
# Epoch 19/100
# 362/362 - 2s - loss: 16.4472 - val_loss: 14.7322 - 2s/epoch - 5ms/step
# Epoch 20/100
# 362/362 - 2s - loss: 14.6762 - val_loss: 16.5975 - 2s/epoch - 6ms/step
# Epoch 21/100
# 362/362 - 2s - loss: 15.0477 - val_loss: 18.1752 - 2s/epoch - 5ms/step
# Epoch 22/100
# 362/362 - 1s - loss: 15.6210 - val_loss: 16.2607 - 1s/epoch - 4ms/step
# Epoch 23/100
# 362/362 - 1s - loss: 15.2478 - val_loss: 16.9093 - 1s/epoch - 3ms/step
# Epoch 24/100
# 362/362 - 1s - loss: 15.0911 - val_loss: 16.0012 - 1s/epoch - 4ms/step
# Epoch 25/100
# 362/362 - 1s - loss: 15.4966 - val_loss: 16.2706 - 1s/epoch - 4ms/step
# Epoch 26/100
# 362/362 - 1s - loss: 15.2435 - val_loss: 16.9220 - 1s/epoch - 4ms/step
# Epoch 27/100
# 362/362 - 1s - loss: 14.5113 - val_loss: 16.1189 - 1s/epoch - 4ms/step
# Epoch 28/100
# 362/362 - 1s - loss: 15.5041 - val_loss: 15.8410 - 1s/epoch - 3ms/step
# Epoch 29/100
# 362/362 - 1s - loss: 14.8962 - val_loss: 14.3779 - 1s/epoch - 3ms/step
# Epoch 30/100
# 362/362 - 1s - loss: 14.0004 - val_loss: 14.2854 - 1s/epoch - 3ms/step
# Epoch 31/100
# 362/362 - 1s - loss: 14.6024 - val_loss: 14.3228 - 898ms/epoch - 2ms/step
# Epoch 32/100
# 362/362 - 1s - loss: 14.7490 - val_loss: 14.4337 - 1s/epoch - 3ms/step
# Epoch 33/100
# 362/362 - 1s - loss: 13.4833 - val_loss: 17.0354 - 931ms/epoch - 3ms/step
# Epoch 34/100
# 362/362 - 1s - loss: 13.2021 - val_loss: 14.7161 - 701ms/epoch - 2ms/step
# Epoch 35/100
# 362/362 - 1s - loss: 14.8115 - val_loss: 14.6841 - 698ms/epoch - 2ms/step
# Epoch 36/100
# 362/362 - 1s - loss: 13.4724 - val_loss: 16.4834 - 689ms/epoch - 2ms/step
# Epoch 37/100
# 362/362 - 1s - loss: 13.8702 - val_loss: 15.6167 - 654ms/epoch - 2ms/step
# Epoch 38/100
# 362/362 - 1s - loss: 14.0223 - val_loss: 18.1993 - 655ms/epoch - 2ms/step
# Epoch 39/100
# 362/362 - 1s - loss: 14.3761 - val_loss: 17.4233 - 677ms/epoch - 2ms/step
# Epoch 40/100
# 362/362 - 1s - loss: 13.0400 - val_loss: 15.1916 - 680ms/epoch - 2ms/step
# Epoch 41/100
# 362/362 - 1s - loss: 13.8086 - val_loss: 14.6540 - 658ms/epoch - 2ms/step
# Epoch 42/100
# 362/362 - 1s - loss: 13.4606 - val_loss: 16.4574 - 657ms/epoch - 2ms/step
# Epoch 43/100
# 362/362 - 1s - loss: 14.5616 - val_loss: 15.6432 - 662ms/epoch - 2ms/step
# Epoch 44/100
# 362/362 - 1s - loss: 14.1506 - val_loss: 14.9148 - 683ms/epoch - 2ms/step
# Epoch 45/100
# 362/362 - 1s - loss: 13.2171 - val_loss: 16.7116 - 689ms/epoch - 2ms/step
# Epoch 46/100
# 362/362 - 1s - loss: 13.4194 - val_loss: 15.3919 - 670ms/epoch - 2ms/step
# Epoch 47/100
# 362/362 - 1s - loss: 14.4291 - val_loss: 15.1918 - 695ms/epoch - 2ms/step
# Epoch 48/100
# 362/362 - 1s - loss: 13.5215 - val_loss: 15.5461 - 829ms/epoch - 2ms/step
# Epoch 49/100
# 362/362 - 1s - loss: 12.6190 - val_loss: 15.0333 - 1s/epoch - 3ms/step
# Epoch 50/100
# 362/362 - 1s - loss: 13.9856 - val_loss: 15.4356 - 988ms/epoch - 3ms/step
# Epoch 51/100
# 362/362 - 1s - loss: 13.0311 - val_loss: 15.7613 - 1s/epoch - 3ms/step
# Epoch 52/100
# 362/362 - 1s - loss: 12.9196 - val_loss: 14.7482 - 945ms/epoch - 3ms/step
# Epoch 53/100
# 362/362 - 1s - loss: 13.2896 - val_loss: 15.3681 - 664ms/epoch - 2ms/step
# Epoch 54/100
# 362/362 - 1s - loss: 12.5934 - val_loss: 15.4934 - 693ms/epoch - 2ms/step
# Epoch 55/100
# 362/362 - 1s - loss: 12.5251 - val_loss: 14.8066 - 692ms/epoch - 2ms/step
# Epoch 56/100
# 362/362 - 1s - loss: 12.9162 - val_loss: 20.0955 - 701ms/epoch - 2ms/step
# Epoch 57/100
# 362/362 - 1s - loss: 12.1423 - val_loss: 15.2968 - 662ms/epoch - 2ms/step
# Epoch 58/100
# 362/362 - 1s - loss: 12.6526 - val_loss: 15.9363 - 688ms/epoch - 2ms/step
# Epoch 59/100
# 362/362 - 1s - loss: 12.4641 - val_loss: 15.3601 - 661ms/epoch - 2ms/step
# Epoch 60/100
# 362/362 - 1s - loss: 12.4922 - val_loss: 17.2301 - 678ms/epoch - 2ms/step
# Epoch 61/100
# 362/362 - 1s - loss: 11.9808 - val_loss: 16.1252 - 688ms/epoch - 2ms/step
# Epoch 62/100
# 362/362 - 1s - loss: 12.9026 - val_loss: 17.5395 - 650ms/epoch - 2ms/step
# Epoch 63/100
# 362/362 - 1s - loss: 12.0196 - val_loss: 16.0003 - 678ms/epoch - 2ms/step
# Epoch 64/100
# 362/362 - 1s - loss: 12.0634 - val_loss: 14.8490 - 646ms/epoch - 2ms/step
# Epoch 65/100
# 362/362 - 1s - loss: 12.2496 - val_loss: 16.9091 - 701ms/epoch - 2ms/step
# Epoch 66/100
# 362/362 - 1s - loss: 12.8448 - val_loss: 16.2791 - 702ms/epoch - 2ms/step
# Epoch 67/100
# 362/362 - 1s - loss: 11.4506 - val_loss: 16.2502 - 1s/epoch - 3ms/step
# Epoch 68/100
# 362/362 - 1s - loss: 11.4635 - val_loss: 17.8775 - 944ms/epoch - 3ms/step
# Epoch 69/100
# 362/362 - 1s - loss: 13.6241 - val_loss: 19.6163 - 1s/epoch - 3ms/step
# Epoch 70/100
# 362/362 - 1s - loss: 11.8416 - val_loss: 15.8803 - 950ms/epoch - 3ms/step
# Epoch 71/100
# 362/362 - 1s - loss: 12.6799 - val_loss: 15.4751 - 991ms/epoch - 3ms/step
# Epoch 72/100
# 362/362 - 1s - loss: 11.6895 - val_loss: 24.6307 - 666ms/epoch - 2ms/step
# Epoch 73/100
# 362/362 - 1s - loss: 12.2326 - val_loss: 15.1623 - 668ms/epoch - 2ms/step
# Epoch 74/100
# 362/362 - 1s - loss: 11.5018 - val_loss: 15.9334 - 655ms/epoch - 2ms/step
# Epoch 75/100
# 362/362 - 1s - loss: 12.5288 - val_loss: 14.4655 - 696ms/epoch - 2ms/step
# Epoch 76/100
# 362/362 - 1s - loss: 12.3483 - val_loss: 15.8331 - 698ms/epoch - 2ms/step
# Epoch 77/100
# 362/362 - 1s - loss: 11.6083 - val_loss: 16.5039 - 690ms/epoch - 2ms/step
# Epoch 78/100
# 362/362 - 1s - loss: 12.2812 - val_loss: 15.7352 - 658ms/epoch - 2ms/step
# Epoch 79/100
# 362/362 - 1s - loss: 11.3926 - val_loss: 21.2650 - 659ms/epoch - 2ms/step
# Epoch 80/100
# 362/362 - 1s - loss: 11.7735 - val_loss: 16.3321 - 705ms/epoch - 2ms/step
# Epoch 81/100
# 362/362 - 1s - loss: 11.7451 - val_loss: 17.6430 - 696ms/epoch - 2ms/step
# Epoch 82/100
# 362/362 - 1s - loss: 11.8217 - val_loss: 15.0336 - 653ms/epoch - 2ms/step
# Epoch 83/100
# 362/362 - 1s - loss: 10.8243 - val_loss: 15.3027 - 644ms/epoch - 2ms/step
# Epoch 84/100
# 362/362 - 1s - loss: 11.5272 - val_loss: 15.4613 - 654ms/epoch - 2ms/step
# Epoch 85/100
# 362/362 - 1s - loss: 11.3557 - val_loss: 15.1627 - 664ms/epoch - 2ms/step
# Epoch 86/100
# 362/362 - 1s - loss: 11.3614 - val_loss: 14.1235 - 920ms/epoch - 3ms/step
# Epoch 87/100
# 362/362 - 1s - loss: 11.1338 - val_loss: 16.1050 - 1s/epoch - 3ms/step
# Epoch 88/100
# 362/362 - 1s - loss: 11.7202 - val_loss: 16.6899 - 1s/epoch - 3ms/step
# Epoch 89/100
# 362/362 - 1s - loss: 11.5566 - val_loss: 15.1775 - 1s/epoch - 3ms/step
# Epoch 90/100
# 362/362 - 1s - loss: 11.2867 - val_loss: 15.0185 - 951ms/epoch - 3ms/step
# Epoch 91/100
# 362/362 - 1s - loss: 11.5958 - val_loss: 19.0350 - 657ms/epoch - 2ms/step
# Epoch 92/100
# 362/362 - 1s - loss: 11.6555 - val_loss: 13.8193 - 664ms/epoch - 2ms/step
# Epoch 93/100
# 362/362 - 1s - loss: 11.5999 - val_loss: 15.2457 - 691ms/epoch - 2ms/step
# Epoch 94/100
# 362/362 - 1s - loss: 11.5128 - val_loss: 19.3907 - 698ms/epoch - 2ms/step
# Epoch 95/100
# 362/362 - 1s - loss: 13.8178 - val_loss: 14.9892 - 673ms/epoch - 2ms/step
# Epoch 96/100
# 362/362 - 1s - loss: 11.8232 - val_loss: 14.9699 - 697ms/epoch - 2ms/step
# Epoch 97/100
# 362/362 - 1s - loss: 11.3428 - val_loss: 17.9400 - 706ms/epoch - 2ms/step
# Epoch 98/100
# 362/362 - 1s - loss: 11.4951 - val_loss: 15.1449 - 659ms/epoch - 2ms/step
# Epoch 99/100
# 362/362 - 1s - loss: 11.3938 - val_loss: 15.7083 - 643ms/epoch - 2ms/step
# Epoch 100/100
# 362/362 - 1s - loss: 10.9613 - val_loss: 18.0167 - 697ms/epoch - 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# ANN - MAE: 2.4721318223325914, RMSE: 5.338223822714584, R²: 0.7720000731777069
